# %% [markdown]
# # Activité 1

# %% [markdown]
# On rappelle la définition de la suite de Fibonacci:
#
# * $u_0 = 0$
# * $u_1 = 1$
# * pour tout $n \in \mathbb{N} : u_{n+2} = u_{n}+u_{n+1}$

# %% [markdown]
# 1. Calculer $u_5$ à la main.
# 2. Compléter la définition de la `fonction fibo(n)` pour qu'elle renvoie le terme $u_n$.

# %%
def fibo(n):
    if n <= 1:
        return n
    return fibo(n-1)+fibo(n-2)

# %%
fibo(4)
# Out:
# 3

# %% [markdown]
# 3. Écrire l'arbre d'appels de `fibo(4)`

# %%
def appels_recursifs_fibo(n, depth=0):
    space= '        '
    if n <= 1:
        print(space * depth, end='')
        print(f'fibo({n})={n}')
        return n
    print(space * depth, end='')
    print(f'fibo({n})=fibo({n-1})+fibo({n-2})')
    return appels_recursifs_fibo(n-1, depth+1)+appels_recursifs_fibo(n-2,depth+1)

appels_recursifs_fibo(4)
# Out:
# fibo(4)=fibo(3)+fibo(2)
#         fibo(3)=fibo(2)+fibo(1)
#                 fibo(2)=fibo(1)+fibo(0)
#                         fibo(1)=1
#                         fibo(0)=0
#                 fibo(1)=1
#         fibo(2)=fibo(1)+fibo(0)
#                 fibo(1)=1
#                 fibo(0)=0
# 3

# %%
def compte_appels_recursifs_fibo(n):
    if n <= 1:
        return 0
    return 2+compte_appels_recursifs_fibo(n-1)+compte_appels_recursifs_fibo(n-2)

compte_appels_recursifs_fibo(50)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-aa939247154e> in <module>()
#       4     return 2+compte_appels_recursifs_fibo(n-1)+compte_appels_recursifs_fibo(n-2)
#       5
# ----> 6 compte_appels_recursifs_fibo(50)
#
# <ipython-input-12-aa939247154e> in compte_appels_recursifs_fibo(n)
#       2     if n <= 1:
#       3         return 0
# ----> 4     return 2+compte_appels_recursifs_fibo(n-1)+compte_appels_recursifs_fibo(n-2)
#       5
#       6 compte_appels_recursifs_fibo(50)
#
# <ipython-input-12-aa939247154e> in compte_appels_recursifs_fibo(n)
#       2     if n <= 1:
#       3         return 0
# ----> 4     return 2+compte_appels_recursifs_fibo(n-1)+compte_appels_recursifs_fibo(n-2)
#       5
#       6 compte_appels_recursifs_fibo(50)
#
# <ipython-input-12-aa939247154e> in compte_appels_recursifs_fibo(n)
#       2     if n <= 1:
#       3         return 0
# ----> 4     return 2+compte_appels_recursifs_fibo(n-1)+compte_appels_recursifs_fibo(n-2)
#       5
#       6 compte_appels_recursifs_fibo(50)
#
# <ipython-input-12-aa939247154e> in compte_appels_recursifs_fibo(n)
#       2     if n <= 1:
#       3         return 0
# ----> 4     return 2+compte_appels_recursifs_fibo(n-1)+compte_appels_recursifs_fibo(n-2)
#       5
#       6 compte_appels_recursifs_fibo(50)
#
# <ipython-input-12-aa939247154e> in compte_appels_recursifs_fibo(n)
#       2     if n <= 1:
#       3         return 0
# ----> 4     return 2+compte_appels_recursifs_fibo(n-1)+compte_appels_recursifs_fibo(n-2)
#       5
#       6 compte_appels_recursifs_fibo(50)
#
# <ipython-input-12-aa939247154e> in compte_appels_recursifs_fibo(n)
#       2     if n <= 1:
#       3         return 0
# ----> 4     return 2+compte_appels_recursifs_fibo(n-1)+compte_appels_recursifs_fibo(n-2)
#       5
#       6 compte_appels_recursifs_fibo(50)
#
# <ipython-input-12-aa939247154e> in compte_appels_recursifs_fibo(n)
#       2     if n <= 1:
#       3         return 0
# ----> 4     return 2+compte_appels_recursifs_fibo(n-1)+compte_appels_recursifs_fibo(n-2)
#       5
#       6 compte_appels_recursifs_fibo(50)
#
# <ipython-input-12-aa939247154e> in compte_appels_recursifs_fibo(n)
#       2     if n <= 1:
#       3         return 0
# ----> 4     return 2+compte_appels_recursifs_fibo(n-1)+compte_appels_recursifs_fibo(n-2)
#       5
#       6 compte_appels_recursifs_fibo(50)
#
# <ipython-input-12-aa939247154e> in compte_appels_recursifs_fibo(n)
#       2     if n <= 1:
#       3         return 0
# ----> 4     return 2+compte_appels_recursifs_fibo(n-1)+compte_appels_recursifs_fibo(n-2)
#       5
#       6 compte_appels_recursifs_fibo(50)
#
# <ipython-input-12-aa939247154e> in compte_appels_recursifs_fibo(n)
#       2     if n <= 1:
#       3         return 0
# ----> 4     return 2+compte_appels_recursifs_fibo(n-1)+compte_appels_recursifs_fibo(n-2)
#       5
#       6 compte_appels_recursifs_fibo(50)
#
# <ipython-input-12-aa939247154e> in compte_appels_recursifs_fibo(n)
#       2     if n <= 1:
#       3         return 0
# ----> 4     return 2+compte_appels_recursifs_fibo(n-1)+compte_appels_recursifs_fibo(n-2)
#       5
#       6 compte_appels_recursifs_fibo(50)
#
# <ipython-input-12-aa939247154e> in compte_appels_recursifs_fibo(n)
#       2     if n <= 1:
#       3         return 0
# ----> 4     return 2+compte_appels_recursifs_fibo(n-1)+compte_appels_recursifs_fibo(n-2)
#       5
#       6 compte_appels_recursifs_fibo(50)
#
# <ipython-input-12-aa939247154e> in compte_appels_recursifs_fibo(n)
#       2     if n <= 1:
#       3         return 0
# ----> 4     return 2+compte_appels_recursifs_fibo(n-1)+compte_appels_recursifs_fibo(n-2)
#       5
#       6 compte_appels_recursifs_fibo(50)
#
# <ipython-input-12-aa939247154e> in compte_appels_recursifs_fibo(n)
#       2     if n <= 1:
#       3         return 0
# ----> 4     return 2+compte_appels_recursifs_fibo(n-1)+compte_appels_recursifs_fibo(n-2)
#       5
#       6 compte_appels_recursifs_fibo(50)
#
# <ipython-input-12-aa939247154e> in compte_appels_recursifs_fibo(n)
#       2     if n <= 1:
#       3         return 0
# ----> 4     return 2+compte_appels_recursifs_fibo(n-1)+compte_appels_recursifs_fibo(n-2)
#       5
#       6 compte_appels_recursifs_fibo(50)
#
# <ipython-input-12-aa939247154e> in compte_appels_recursifs_fibo(n)
#       2     if n <= 1:
#       3         return 0
# ----> 4     return 2+compte_appels_recursifs_fibo(n-1)+compte_appels_recursifs_fibo(n-2)
#       5
#       6 compte_appels_recursifs_fibo(50)
#
# <ipython-input-12-aa939247154e> in compte_appels_recursifs_fibo(n)
#       2     if n <= 1:
#       3         return 0
# ----> 4     return 2+compte_appels_recursifs_fibo(n-1)+compte_appels_recursifs_fibo(n-2)
#       5
#       6 compte_appels_recursifs_fibo(50)
#
# <ipython-input-12-aa939247154e> in compte_appels_recursifs_fibo(n)
#       2     if n <= 1:
#       3         return 0
# ----> 4     return 2+compte_appels_recursifs_fibo(n-1)+compte_appels_recursifs_fibo(n-2)
#       5
#       6 compte_appels_recursifs_fibo(50)
#
# <ipython-input-12-aa939247154e> in compte_appels_recursifs_fibo(n)
#       2     if n <= 1:
#       3         return 0
# ----> 4     return 2+compte_appels_recursifs_fibo(n-1)+compte_appels_recursifs_fibo(n-2)
#       5
#       6 compte_appels_recursifs_fibo(50)
#
# <ipython-input-12-aa939247154e> in compte_appels_recursifs_fibo(n)
#       2     if n <= 1:
#       3         return 0
# ----> 4     return 2+compte_appels_recursifs_fibo(n-1)+compte_appels_recursifs_fibo(n-2)
#       5
#       6 compte_appels_recursifs_fibo(50)
#
# <ipython-input-12-aa939247154e> in compte_appels_recursifs_fibo(n)
#       2     if n <= 1:
#       3         return 0
# ----> 4     return 2+compte_appels_recursifs_fibo(n-1)+compte_appels_recursifs_fibo(n-2)
#       5
#       6 compte_appels_recursifs_fibo(50)
#
# <ipython-input-12-aa939247154e> in compte_appels_recursifs_fibo(n)
#       2     if n <= 1:
#       3         return 0
# ----> 4     return 2+compte_appels_recursifs_fibo(n-1)+compte_appels_recursifs_fibo(n-2)
#       5
#       6 compte_appels_recursifs_fibo(50)
#
# <ipython-input-12-aa939247154e> in compte_appels_recursifs_fibo(n)
#       2     if n <= 1:
#       3         return 0
# ----> 4     return 2+compte_appels_recursifs_fibo(n-1)+compte_appels_recursifs_fibo(n-2)
#       5
#       6 compte_appels_recursifs_fibo(50)
#
# <ipython-input-12-aa939247154e> in compte_appels_recursifs_fibo(n)
#       2     if n <= 1:
#       3         return 0
# ----> 4     return 2+compte_appels_recursifs_fibo(n-1)+compte_appels_recursifs_fibo(n-2)
#       5
#       6 compte_appels_recursifs_fibo(50)
#
# <ipython-input-12-aa939247154e> in compte_appels_recursifs_fibo(n)
#       2     if n <= 1:
#       3         return 0
# ----> 4     return 2+compte_appels_recursifs_fibo(n-1)+compte_appels_recursifs_fibo(n-2)
#       5
#       6 compte_appels_recursifs_fibo(50)
#
# <ipython-input-12-aa939247154e> in compte_appels_recursifs_fibo(n)
#       2     if n <= 1:
#       3         return 0
# ----> 4     return 2+compte_appels_recursifs_fibo(n-1)+compte_appels_recursifs_fibo(n-2)
#       5
#       6 compte_appels_recursifs_fibo(50)
#
# <ipython-input-12-aa939247154e> in compte_appels_recursifs_fibo(n)
#       2     if n <= 1:
#       3         return 0
# ----> 4     return 2+compte_appels_recursifs_fibo(n-1)+compte_appels_recursifs_fibo(n-2)
#       5
#       6 compte_appels_recursifs_fibo(50)
#
# <ipython-input-12-aa939247154e> in compte_appels_recursifs_fibo(n)
#       2     if n <= 1:
#       3         return 0
# ----> 4     return 2+compte_appels_recursifs_fibo(n-1)+compte_appels_recursifs_fibo(n-2)
#       5
#       6 compte_appels_recursifs_fibo(50)
#
# <ipython-input-12-aa939247154e> in compte_appels_recursifs_fibo(n)
#       2     if n <= 1:
#       3         return 0
# ----> 4     return 2+compte_appels_recursifs_fibo(n-1)+compte_appels_recursifs_fibo(n-2)
#       5
#       6 compte_appels_recursifs_fibo(50)
#
# <ipython-input-12-aa939247154e> in compte_appels_recursifs_fibo(n)
#       2     if n <= 1:
#       3         return 0
# ----> 4     return 2+compte_appels_recursifs_fibo(n-1)+compte_appels_recursifs_fibo(n-2)
#       5
#       6 compte_appels_recursifs_fibo(50)
#
# <ipython-input-12-aa939247154e> in compte_appels_recursifs_fibo(n)
#       2     if n <= 1:
#       3         return 0
# ----> 4     return 2+compte_appels_recursifs_fibo(n-1)+compte_appels_recursifs_fibo(n-2)
#       5
#       6 compte_appels_recursifs_fibo(50)
#
# <ipython-input-12-aa939247154e> in compte_appels_recursifs_fibo(n)
#       2     if n <= 1:
#       3         return 0
# ----> 4     return 2+compte_appels_recursifs_fibo(n-1)+compte_appels_recursifs_fibo(n-2)
#       5
#       6 compte_appels_recursifs_fibo(50)
#
# <ipython-input-12-aa939247154e> in compte_appels_recursifs_fibo(n)
#       2     if n <= 1:
#       3         return 0
# ----> 4     return 2+compte_appels_recursifs_fibo(n-1)+compte_appels_recursifs_fibo(n-2)
#       5
#       6 compte_appels_recursifs_fibo(50)
#
# <ipython-input-12-aa939247154e> in compte_appels_recursifs_fibo(n)
#       2     if n <= 1:
#       3         return 0
# ----> 4     return 2+compte_appels_recursifs_fibo(n-1)+compte_appels_recursifs_fibo(n-2)
#       5
#       6 compte_appels_recursifs_fibo(50)
#
# <ipython-input-12-aa939247154e> in compte_appels_recursifs_fibo(n)
#       2     if n <= 1:
#       3         return 0
# ----> 4     return 2+compte_appels_recursifs_fibo(n-1)+compte_appels_recursifs_fibo(n-2)
#       5
#       6 compte_appels_recursifs_fibo(50)
#
# <ipython-input-12-aa939247154e> in compte_appels_recursifs_fibo(n)
#       2     if n <= 1:
#       3         return 0
# ----> 4     return 2+compte_appels_recursifs_fibo(n-1)+compte_appels_recursifs_fibo(n-2)
#       5
#       6 compte_appels_recursifs_fibo(50)
#
# <ipython-input-12-aa939247154e> in compte_appels_recursifs_fibo(n)
# ----> 1 def compte_appels_recursifs_fibo(n):
#       2     if n <= 1:
#       3         return 0
#       4     return 2+compte_appels_recursifs_fibo(n-1)+compte_appels_recursifs_fibo(n-2)
#       5
#
# KeyboardInterrupt:

# %% [markdown]
# résultat attendu : 1 125 899 906 842 624

# %% [markdown]
# 4. Comment faire pour éviter d'exécuter plusieurs fois le même appel récursif?
